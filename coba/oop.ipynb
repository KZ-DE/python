# %% [markdown]
# # membuat template Hero

# %%
class Hero :
    # deklarasi variable
    jumblah = 0
    
    def __init__(self,Name:str, Healt:int, Power:int, Armor:int, Mana:int) -> str | dict :
        ''' fungsi yang berguna untuk template yang akan di gunakan oleh hero '''
        
        self.name = Name
        self.healt = Healt
        self.power = Power
        self.armor = Armor
        self.mana = Mana
        
        Hero.jumblah += 1
        
        pass
    
    def list(self)-> dict:
        '''untuk melihat informasi lengakap hero'''
        
        print(self.__dict__)
        
    def serangp1(self,p2):
        '''serang'''

# %% [markdown]
# #### deklarasi hero

# %%
bejo = Hero("bejo", 200, 140, 90, 82)
sudrun = Hero("sudrun", 140, 175, 170, 25)

# %% [markdown]
# membuat class untuk serangan
